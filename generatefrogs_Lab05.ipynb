# %% [markdown]
# <a href="https://colab.research.google.com/github/LilyBouldin/cosc470s24/blob/main/generatefrogs_Lab05.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
from numpy import expand_dims
from numpy import zeros
from numpy import ones
from numpy import vstack
from numpy.random import randn
from numpy.random import randint
from keras.datasets.cifar10 import load_data
from keras.optimizers import Adam
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import Reshape
from keras.layers import Flatten
from keras.layers import Conv2D
from keras.layers import Conv2DTranspose
from keras.layers import LeakyReLU
from keras.layers import Dropout
from matplotlib import pyplot

# %%
def define_discriminator(input_shape=(32, 32, 3)):
    """
    Define the discriminator model structure for the DCGAN.

    Parameters:
    - input_shape: tuple, shape of the input images. Default is (32, 32, 3) for 32x32 RGB images.

    Returns:
    - Compiled Keras model of the discriminator.
    """
    model = Sequential()

    # Initial convolutional layer with input shape specification
    model.add(Conv2D(64, (3, 3), padding='same', input_shape=input_shape))
    model.add(LeakyReLU(alpha=0.2))

    # First downsample: reduces image dimensions by half, increases depth
    model.add(Conv2D(128, (3, 3), strides=(2, 2), padding='same'))
    model.add(LeakyReLU(alpha=0.2))

    # Second downsample
    model.add(Conv2D(128, (3, 3), strides=(2, 2), padding='same'))
    model.add(LeakyReLU(alpha=0.2))

    # Third downsample
    model.add(Conv2D(256, (3, 3), strides=(2, 2), padding='same'))
    model.add(LeakyReLU(alpha=0.2))

    # Flatten the output of the last convolutional layer
    model.add(Flatten())

    # Dropout for regularization (helps prevent overfitting)
    model.add(Dropout(0.4))

    # Output layer: binary classification (real or fake)
    model.add(Dense(1, activation='sigmoid'))

    # Compiling the model with Adam optimizer and binary crossentropy loss
    # Adjusted learning rate and beta_1 for stable training
    optimizer = Adam(learning_rate=0.0002, beta_1=0.5)
    model.compile(loss='binary_crossentropy', optimizer=optimizer, metrics=['accuracy'])

    return model

# %%
def define_generator(latent_dim):
    """
    Define the generator model structure for the DCGAN.

    Parameters:
    - latent_dim: int, size of the latent space (noise vector input).

    Returns:
    - Uncompiled Keras model of the generator.
    """
    model = Sequential()

    # Foundation for 4x4 image
    n_nodes = 256 * 4 * 4
    model.add(Dense(n_nodes, input_dim=latent_dim))
    model.add(LeakyReLU(alpha=0.2))
    model.add(Reshape((4, 4, 256)))

    # Upsample to 8x8
    model.add(Conv2DTranspose(128, (4, 4), strides=(2, 2), padding='same'))
    model.add(LeakyReLU(alpha=0.2))

    # Upsample to 16x16
    model.add(Conv2DTranspose(128, (4, 4), strides=(2, 2), padding='same'))
    model.add(LeakyReLU(alpha=0.2))

    # Upsample to 32x32
    model.add(Conv2DTranspose(128, (4, 4), strides=(2, 2), padding='same'))
    model.add(LeakyReLU(alpha=0.2))

    # Output layer with tanh activation for generating images
    model.add(Conv2D(3, (3, 3), activation='tanh', padding='same'))

    return model

# %%
def define_gan(generator_model, discriminator_model):
    """
    Define the combined GAN model for training the generator.

    Parameters:
    - generator_model: Model, the generator component of the GAN.
    - discriminator_model: Model, the discriminator component of the GAN, set to non-trainable.

    Returns:
    - Compiled Keras model of the combined GAN, ready for training the generator.
    """
    # Set discriminator weights to non-trainable (only when part of the combined model)
    discriminator_model.trainable = False

    # Initialize the combined model
    model = Sequential()

    # Add generator
    model.add(generator_model)

    # Add discriminator
    model.add(discriminator_model)

    # Compile the combined model
    # The optimizer and loss function are set up for training the generator
    optimizer = Adam(learning_rate=0.0002, beta_1=0.5)
    model.compile(loss='binary_crossentropy', optimizer=optimizer)

    return model

# %%
def load_real_samples():
    """
    Load and prepare CIFAR-10 frog images.

    Returns:
    - X: numpy array, CIFAR-10 frog images normalized to [-1, 1].
    """
    # Load CIFAR-10 dataset
    (trainX, trainy), (_, _) = load_data()

    # Filter for frogs, which are class 6
    indices = np.where(trainy == 6)
    trainX = trainX[indices[0]]

    # Convert image data from unsigned integers to floats
    X = trainX.astype('float32')

    # Normalize the images from [0,255] to [-1,1]
    X = (X - 127.5) / 127.5

    return X

# Load the real samples for use
a = load_real_samples()
# Out:
# Downloading data from https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz
# 170498071/170498071 [==============================] - 2s 0us/step

# %%
def generate_real_samples(dataset, n_samples):
    """
    Select a random subset of real samples from a dataset.

    Parameters:
    - dataset: numpy array, the collection of images to select real samples from.
    - n_samples: int, the number of real samples to select.

    Returns:
    - X: numpy array, the selected images.
    - y: numpy array, an array of labels marking the selected images as real.
    """
    # Choose random instances
    ix = randint(0, dataset.shape[0], n_samples)

    # Retrieve selected images
    X = dataset[ix]

    # Generate 'real' class labels (1) for the selected samples
    y = ones((n_samples, 1))

    return X, y

# %%
def generate_latent_points(latent_dim, n_samples):
    """
    Generate points in the latent space as input for the generator.

    Parameters:
    - latent_dim: int, the dimensionality of the latent space.
    - n_samples: int, the number of samples to generate in the latent space.

    Returns:
    - x_input: numpy array, batch of latent points reshaped for the generator network.
    """
    # Generate points in the latent space
    x_input = randn(latent_dim * n_samples)

    # Reshape into a batch of inputs for the network
    x_input = x_input.reshape(n_samples, latent_dim)

    return x_input

# %%
def generate_fake_samples(generator_model, latent_dim, n_samples):
    """
    Use the generator to generate 'n' fake examples, along with their class labels.

    Parameters:
    - generator_model: Model, the generator component of the GAN.
    - latent_dim: int, the dimensionality of the latent space.
    - n_samples: int, the number of fake samples to generate.

    Returns:
    - X: numpy array, the generated fake images.
    - y: numpy array, an array of labels marking the images as fake.
    """
    # Generate points in latent space
    x_input = generate_latent_points(latent_dim, n_samples)

    # Use the generator model to predict (generate) outputs
    X = generator_model.predict(x_input)

    # Create 'fake' class labels (0) for the generated images
    y = zeros((n_samples, 1))

    return X, y

# %%
def save_plot(examples, epoch, n=7):
    """
    Create and save a plot of generated images.

    Parameters:
    - examples: numpy array, the generated images to plot.
    - epoch: int, the current epoch number, used to name the saved file.
    - n: int, the number of images to display along each dimension of the grid. Default is 7.
    """
    # Scale from [-1,1] to [0,1] for plotting
    examples = (examples + 1) / 2.0

    # Plot images
    for i in range(n * n):
        # Define subplot
        pyplot.subplot(n, n, 1 + i)
        # Turn off axis
        pyplot.axis('off')
        # Plot raw pixel data
        pyplot.imshow(examples[i])

    # Save plot to file
    filename = f'generated_plot_e{epoch+1:03d}.png'
    pyplot.savefig(filename)
    pyplot.close()

# %%
def summarize_performance(epoch, generator_model, discriminator_model, dataset, latent_dim, n_samples=150):
    """
    Evaluate the discriminator, plot generated images, and save the generator model.

    Parameters:
    - epoch: int, the current training epoch.
    - generator_model: Model, the generator component of the GAN.
    - discriminator_model: Model, the discriminator component of the GAN.
    - dataset: numpy array, the dataset of real images.
    - latent_dim: int, the dimensionality of the latent space.
    - n_samples: int, the number of samples to generate for evaluation. Default is 150.
    """
    # Prepare real samples and evaluate discriminator on real examples
    X_real, y_real = generate_real_samples(dataset, n_samples)
    _, acc_real = discriminator_model.evaluate(X_real, y_real, verbose=0)

    # Prepare fake examples and evaluate discriminator on fake examples
    x_fake, y_fake = generate_fake_samples(generator_model, latent_dim, n_samples)
    _, acc_fake = discriminator_model.evaluate(x_fake, y_fake, verbose=0)

    # Summarize discriminator performance
    print(f'>Accuracy real: {acc_real*100:.0f}%, fake: {acc_fake*100:.0f}%')

    # Save plot of fake images
    save_plot(x_fake, epoch)

    # Save the generator model
    filename = f'generator_model_{epoch+1:03d}.h5'
    generator_model.save(filename)

# %%
def summarize_performance(epoch, generator_model, discriminator_model, dataset, latent_dim, n_samples=150):
    """
    Evaluate the discriminator, plot generated images, and save the generator model.

    Parameters:
    - epoch: int, the current training epoch.
    - generator_model: Model, the generator component of the GAN.
    - discriminator_model: Model, the discriminator component of the GAN.
    - dataset: numpy array, the dataset of real images.
    - latent_dim: int, the dimensionality of the latent space.
    - n_samples: int, the number of samples to generate for evaluation. Default is 150.
    """
    # Prepare real samples and evaluate discriminator on real examples
    X_real, y_real = generate_real_samples(dataset, n_samples)
    _, acc_real = discriminator_model.evaluate(X_real, y_real, verbose=0)

    # Prepare fake examples and evaluate discriminator on fake examples
    x_fake, y_fake = generate_fake_samples(generator_model, latent_dim, n_samples)
    _, acc_fake = discriminator_model.evaluate(x_fake, y_fake, verbose=0)

    # Summarize discriminator performance
    print(f'>Accuracy real: {acc_real*100:.0f}%, fake: {acc_fake*100:.0f}%')

    # Save plot of fake images
    save_plot(x_fake, epoch)

    # Save the generator model
    filename = f'generator_model_{epoch+1:03d}.h5'
    generator_model.save(filename)

def train(generator_model, discriminator_model, gan_model, dataset, latent_dim, n_epochs=200, n_batch=128):
    """
    Train the generator and discriminator of the GAN.

    Parameters:
    - generator_model: Model, the generator component of the GAN.
    - discriminator_model: Model, the discriminator component of the GAN.
    - gan_model: Model, the combined GAN model for updating the generator.
    - dataset: numpy array, the dataset of real images.
    - latent_dim: int, the dimensionality of the latent space.
    - n_epochs: int, the number of epochs to train for. Default is 200.
    - n_batch: int, the size of the batch. Default is 128.
    """
    bat_per_epo = int(dataset.shape[0] / n_batch)
    half_batch = int(n_batch / 2)

    # Manually enumerate epochs
    for epoch in range(n_epochs):
        # Enumerate batches over the training set
        for batch in range(bat_per_epo):
            # Get randomly selected 'real' samples
            X_real, y_real = generate_real_samples(dataset, half_batch)
            # Update discriminator model weights
            d_loss_real = discriminator_model.train_on_batch(X_real, y_real)[0]

            # Generate 'fake' examples
            X_fake, y_fake = generate_fake_samples(generator_model, latent_dim, half_batch)
            # Update discriminator model weights
            d_loss_fake = discriminator_model.train_on_batch(X_fake, y_fake)[0]

            # Prepare points in latent space as input for the generator
            X_gan = generate_latent_points(latent_dim, n_batch)
            # Create inverted labels for the fake samples
            y_gan = ones((n_batch, 1))
            # Update the generator via the discriminator's error
            g_loss = gan_model.train_on_batch(X_gan, y_gan)

            # Summarize loss on this batch
            print(f'>{epoch+1}, {batch+1}/{bat_per_epo}, d_loss_real={d_loss_real:.3f}, d_loss_fake={d_loss_fake:.3f}, g_loss={g_loss:.3f}')

        # Evaluate the model performance, sometimes
        if (epoch + 1) % 10 == 0:
            summarize_performance(epoch, generator_model, discriminator_model, dataset, latent_dim)

# %%
latent_dim = 100

# Create models
d_model = define_discriminator()
g_model = define_generator(latent_dim)
gan_model = define_gan(g_model, d_model)

# Load CIFAR-10 dataset
dataset = load_real_samples()

# Train model(s)
train(g_model, d_model, gan_model, dataset, latent_dim, 50)
# Out:
# 2/2 [==============================] - 0s 8ms/step
# >1, 1/39, d_loss_real=0.709, d_loss_fake=0.695, g_loss=0.692
# 2/2 [==============================] - 0s 3ms/step
# >1, 2/39, d_loss_real=0.653, d_loss_fake=0.697, g_loss=0.691
# 2/2 [==============================] - 0s 8ms/step
# >1, 3/39, d_loss_real=0.603, d_loss_fake=0.701, g_loss=0.687
# 2/2 [==============================] - 0s 4ms/step
# >1, 4/39, d_loss_real=0.530, d_loss_fake=0.711, g_loss=0.679
# 2/2 [==============================] - 0s 5ms/step
# >1, 5/39, d_loss_real=0.437, d_loss_fake=0.733, g_loss=0.660
# 2/2 [==============================] - 0s 4ms/step
# >1, 6/39, d_loss_real=0.295, d_loss_fake=0.778, g_loss=0.636
# 2/2 [==============================] - 0s 5ms/step
# >1, 7/39, d_loss_real=0.207, d_loss_fake=0.834, g_loss=0.619
# 2/2 [==============================] - 0s 4ms/step
# >1, 8/39, d_loss_real=0.156, d_loss_fake=0.870, g_loss=0.632
# 2/2 [==============================] - 0s 4ms/step
# >1, 9/39, d_loss_real=0.141, d_loss_fake=0.848, g_loss=0.670
# 2/2 [==============================] - 0s 4ms/step
# >1, 10/39, d_loss_real=0.122, d_loss_fake=0.816, g_loss=0.714
# 2/2 [==============================] - 0s 4ms/step
# >1, 11/39, d_loss_real=0.147, d_loss_fake=0.801, g_loss=0.760
# 2/2 [==============================] - 0s 4ms/step
# >1, 12/39, d_loss_real=0.187, d_loss_fake=0.813, g_loss=0.809
# 2/2 [==============================] - 0s 4ms/step
# >1, 13/39, d_loss_real=0.191, d_loss_fake=0.805, g_loss=0.864
# 2/2 [==============================] - 0s 3ms/step
# >1, 14/39, d_loss_real=0.277, d_loss_fake=0.747, g_loss=0.921
# 2/2 [==============================] - 0s 5ms/step
# >1, 15/39, d_loss_real=0.358, d_loss_fake=0.710, g_loss=0.931
# 2/2 [==============================] - 0s 5ms/step
# >1, 16/39, d_loss_real=0.424, d_loss_fake=0.741, g_loss=0.872
# 2/2 [==============================] - 0s 8ms/step
# >1, 17/39, d_loss_real=0.534, d_loss_fake=0.737, g_loss=0.792
# 2/2 [==============================] - 0s 4ms/step
# >1, 18/39, d_loss_real=0.514, d_loss_fake=0.750, g_loss=0.764
# 2/2 [==============================] - 0s 4ms/step
# >1, 19/39, d_loss_real=0.430, d_loss_fake=0.728, g_loss=0.765
# 2/2 [==============================] - 0s 3ms/step
# >1, 20/39, d_loss_real=0.407, d_loss_fake=0.691, g_loss=0.775
# 2/2 [==============================] - 0s 5ms/step
# >1, 21/39, d_loss_real=0.256, d_loss_fake=0.663, g_loss=0.788
# 2/2 [==============================] - 0s 4ms/step
# >1, 22/39, d_loss_real=0.356, d_loss_fake=0.669, g_loss=0.769
# 2/2 [==============================] - 0s 5ms/step
# >1, 23/39, d_loss_real=0.207, d_loss_fake=0.680, g_loss=0.753
# 2/2 [==============================] - 0s 4ms/step
# >1, 24/39, d_loss_real=0.167, d_loss_fake=0.697, g_loss=0.739
# 2/2 [==============================] - 0s 4ms/step
# >1, 25/39, d_loss_real=0.144, d_loss_fake=0.771, g_loss=0.711
# 2/2 [==============================] - 0s 5ms/step
# >1, 26/39, d_loss_real=0.133, d_loss_fake=1.130, g_loss=0.558
# 2/2 [==============================] - 0s 5ms/step
# >1, 27/39, d_loss_real=0.089, d_loss_fake=1.430, g_loss=0.490
# 2/2 [==============================] - 0s 4ms/step
# >1, 28/39, d_loss_real=0.112, d_loss_fake=1.192, g_loss=0.657
# 2/2 [==============================] - 0s 4ms/step
# >1, 29/39, d_loss_real=0.164, d_loss_fake=0.730, g_loss=0.976
# 2/2 [==============================] - 0s 6ms/step
# >1, 30/39, d_loss_real=0.216, d_loss_fake=0.507, g_loss=1.150
# 2/2 [==============================] - 0s 5ms/step
# >1, 31/39, d_loss_real=0.221, d_loss_fake=0.521, g_loss=1.018
# 2/2 [==============================] - 0s 5ms/step
# >1, 32/39, d_loss_real=0.200, d_loss_fake=0.634, g_loss=0.835
# 2/2 [==============================] - 0s 5ms/step
# >1, 33/39, d_loss_real=0.158, d_loss_fake=0.823, g_loss=0.655
# 2/2 [==============================] - 0s 5ms/step
# >1, 34/39, d_loss_real=0.185, d_loss_fake=0.990, g_loss=0.567
# 2/2 [==============================] - 0s 5ms/step
# >1, 35/39, d_loss_real=0.106, d_loss_fake=1.126, g_loss=0.547
# 2/2 [==============================] - 0s 7ms/step
# >1, 36/39, d_loss_real=0.143, d_loss_fake=1.061, g_loss=0.595
# 2/2 [==============================] - 0s 5ms/step
# >1, 37/39, d_loss_real=0.125, d_loss_fake=0.907, g_loss=0.722
# 2/2 [==============================] - 0s 5ms/step
# >1, 38/39, d_loss_real=0.249, d_loss_fake=0.714, g_loss=0.925
# 2/2 [==============================] - 0s 4ms/step
# >1, 39/39, d_loss_real=0.281, d_loss_fake=0.521, g_loss=1.199
# 2/2 [==============================] - 0s 5ms/step
# >2, 1/39, d_loss_real=0.372, d_loss_fake=0.402, g_loss=1.361
# 2/2 [==============================] - 0s 5ms/step
# >2, 2/39, d_loss_real=0.287, d_loss_fake=0.360, g_loss=1.389
# 2/2 [==============================] - 0s 6ms/step
# >2, 3/39, d_loss_real=0.338, d_loss_fake=0.387, g_loss=1.273
# 2/2 [==============================] - 0s 5ms/step
# >2, 4/39, d_loss_real=0.372, d_loss_fake=0.440, g_loss=1.112
# 2/2 [==============================] - 0s 4ms/step
# >2, 5/39, d_loss_real=0.293, d_loss_fake=0.509, g_loss=0.968
# 2/2 [==============================] - 0s 5ms/step
# >2, 6/39, d_loss_real=0.163, d_loss_fake=0.541, g_loss=0.921
# 2/2 [==============================] - 0s 5ms/step
# >2, 7/39, d_loss_real=0.194, d_loss_fake=0.560, g_loss=0.892
# 2/2 [==============================] - 0s 5ms/step
# >2, 8/39, d_loss_real=0.160, d_loss_fake=0.574, g_loss=0.870
# 2/2 [==============================] - 0s 4ms/step
# >2, 9/39, d_loss_real=0.155, d_loss_fake=0.586, g_loss=0.856
# 2/2 [==============================] - 0s 8ms/step
# >2, 10/39, d_loss_real=0.076, d_loss_fake=0.589, g_loss=0.850
# 2/2 [==============================] - 0s 4ms/step
# >2, 11/39, d_loss_real=0.152, d_loss_fake=0.608, g_loss=0.843
# 2/2 [==============================] - 0s 4ms/step
# >2, 12/39, d_loss_real=0.063, d_loss_fake=0.587, g_loss=0.861
# 2/2 [==============================] - 0s 5ms/step
# >2, 13/39, d_loss_real=0.064, d_loss_fake=0.573, g_loss=0.882
# 2/2 [==============================] - 0s 4ms/step
# >2, 14/39, d_loss_real=0.043, d_loss_fake=0.560, g_loss=0.915
# 2/2 [==============================] - 0s 5ms/step
# >2, 15/39, d_loss_real=0.070, d_loss_fake=0.543, g_loss=0.939
# 2/2 [==============================] - 0s 4ms/step
# >2, 16/39, d_loss_real=0.038, d_loss_fake=0.555, g_loss=0.977
# 2/2 [==============================] - 0s 6ms/step
# >2, 17/39, d_loss_real=0.080, d_loss_fake=0.587, g_loss=1.021
# 2/2 [==============================] - 0s 6ms/step
# >2, 18/39, d_loss_real=0.060, d_loss_fake=0.621, g_loss=1.082
# 2/2 [==============================] - 0s 5ms/step
# >2, 19/39, d_loss_real=0.126, d_loss_fake=0.668, g_loss=1.210
# 2/2 [==============================] - 0s 5ms/step
# >2, 20/39, d_loss_real=0.083, d_loss_fake=0.449, g_loss=1.550
# 2/2 [==============================] - 0s 6ms/step
# >2, 21/39, d_loss_real=0.133, d_loss_fake=0.295, g_loss=1.666
# 2/2 [==============================] - 0s 5ms/step
# >2, 22/39, d_loss_real=0.229, d_loss_fake=0.334, g_loss=1.393
# 2/2 [==============================] - 0s 5ms/step
# >2, 23/39, d_loss_real=0.104, d_loss_fake=0.378, g_loss=1.244
# 2/2 [==============================] - 0s 3ms/step
# >2, 24/39, d_loss_real=0.045, d_loss_fake=0.368, g_loss=1.253
# 2/2 [==============================] - 0s 5ms/step
# >2, 25/39, d_loss_real=0.052, d_loss_fake=0.350, g_loss=1.305
# 2/2 [==============================] - 0s 4ms/step
# >2, 26/39, d_loss_real=0.076, d_loss_fake=0.343, g_loss=1.310
# 2/2 [==============================] - 0s 5ms/step
# >2, 27/39, d_loss_real=0.017, d_loss_fake=0.382, g_loss=1.267
# 2/2 [==============================] - 0s 5ms/step
# >2, 28/39, d_loss_real=0.007, d_loss_fake=0.518, g_loss=1.262
# 2/2 [==============================] - 0s 5ms/step
# >2, 29/39, d_loss_real=0.017, d_loss_fake=0.641, g_loss=1.687
# 2/2 [==============================] - 0s 5ms/step
# >2, 30/39, d_loss_real=0.069, d_loss_fake=0.241, g_loss=2.105
# 2/2 [==============================] - 0s 4ms/step
# >2, 31/39, d_loss_real=0.073, d_loss_fake=0.438, g_loss=2.126
# 2/2 [==============================] - 0s 7ms/step
# >2, 32/39, d_loss_real=0.130, d_loss_fake=0.608, g_loss=3.464
# 2/2 [==============================] - 0s 5ms/step
# >2, 33/39, d_loss_real=0.227, d_loss_fake=0.061, g_loss=3.377
# 2/2 [==============================] - 0s 5ms/step
# >2, 34/39, d_loss_real=0.218, d_loss_fake=0.225, g_loss=2.062
# 2/2 [==============================] - 0s 5ms/step
# >2, 35/39, d_loss_real=0.210, d_loss_fake=0.461, g_loss=2.096
# 2/2 [==============================] - 0s 4ms/step
# >2, 36/39, d_loss_real=0.197, d_loss_fake=0.249, g_loss=2.676
# 2/2 [==============================] - 0s 6ms/step
# >2, 37/39, d_loss_real=0.227, d_loss_fake=0.175, g_loss=2.729
# 2/2 [==============================] - 0s 5ms/step
# >2, 38/39, d_loss_real=0.291, d_loss_fake=0.242, g_loss=2.960
# 2/2 [==============================] - 0s 5ms/step
# >2, 39/39, d_loss_real=0.155, d_loss_fake=0.159, g_loss=3.187
# 2/2 [==============================] - 0s 5ms/step
# >3, 1/39, d_loss_real=0.144, d_loss_fake=0.169, g_loss=3.333
# 2/2 [==============================] - 0s 5ms/step
# >3, 2/39, d_loss_real=0.253, d_loss_fake=0.345, g_loss=3.413
# 2/2 [==============================] - 0s 5ms/step
# >3, 3/39, d_loss_real=0.688, d_loss_fake=0.742, g_loss=2.999
# 2/2 [==============================] - 0s 7ms/step
# >3, 4/39, d_loss_real=0.725, d_loss_fake=0.195, g_loss=2.321
# 2/2 [==============================] - 0s 5ms/step
# >3, 5/39, d_loss_real=0.369, d_loss_fake=0.555, g_loss=2.371
# 2/2 [==============================] - 0s 4ms/step
# >3, 6/39, d_loss_real=0.336, d_loss_fake=0.136, g_loss=2.563
# 2/2 [==============================] - 0s 3ms/step
# >3, 7/39, d_loss_real=0.305, d_loss_fake=0.242, g_loss=2.364
# 2/2 [==============================] - 0s 4ms/step
# >3, 8/39, d_loss_real=0.074, d_loss_fake=0.123, g_loss=3.068
# 2/2 [==============================] - 0s 3ms/step
# >3, 9/39, d_loss_real=0.177, d_loss_fake=0.128, g_loss=2.750
# 2/2 [==============================] - 0s 5ms/step
# >3, 10/39, d_loss_real=0.228, d_loss_fake=0.235, g_loss=3.283
# 2/2 [==============================] - 0s 3ms/step
# >3, 11/39, d_loss_real=0.234, d_loss_fake=0.196, g_loss=2.480
# 2/2 [==============================] - 0s 5ms/step
# >3, 12/39, d_loss_real=0.229, d_loss_fake=4.230, g_loss=4.346
# 2/2 [==============================] - 0s 4ms/step
# >3, 13/39, d_loss_real=0.809, d_loss_fake=0.007, g_loss=6.277
# 2/2 [==============================] - 0s 5ms/step
# >3, 14/39, d_loss_real=0.249, d_loss_fake=0.081, g_loss=2.629
# 2/2 [==============================] - 0s 5ms/step
# >3, 15/39, d_loss_real=0.115, d_loss_fake=1.632, g_loss=1.832
# 2/2 [==============================] - 0s 5ms/step
# >3, 16/39, d_loss_real=0.605, d_loss_fake=0.217, g_loss=2.375
# 2/2 [==============================] - 0s 4ms/step
# >3, 17/39, d_loss_real=0.813, d_loss_fake=0.245, g_loss=2.092
# 2/2 [==============================] - 0s 5ms/step
# >3, 18/39, d_loss_real=0.480, d_loss_fake=0.372, g_loss=2.349
# 2/2 [==============================] - 0s 3ms/step
# >3, 19/39, d_loss_real=0.690, d_loss_fake=0.243, g_loss=2.407
# 2/2 [==============================] - 0s 6ms/step
# >3, 20/39, d_loss_real=0.662, d_loss_fake=0.365, g_loss=2.482
# 2/2 [==============================] - 0s 3ms/step
# >3, 21/39, d_loss_real=0.549, d_loss_fake=0.238, g_loss=2.665
# 2/2 [==============================] - 0s 5ms/step
# >3, 22/39, d_loss_real=0.678, d_loss_fake=0.236, g_loss=2.685
# 2/2 [==============================] - 0s 3ms/step
# >3, 23/39, d_loss_real=0.428, d_loss_fake=0.120, g_loss=2.828
# 2/2 [==============================] - 0s 5ms/step
# >3, 24/39, d_loss_real=0.503, d_loss_fake=0.127, g_loss=2.713
# 2/2 [==============================] - 0s 5ms/step
# >3, 25/39, d_loss_real=0.384, d_loss_fake=0.149, g_loss=2.715
# 2/2 [==============================] - 0s 6ms/step
# >3, 26/39, d_loss_real=0.317, d_loss_fake=0.134, g_loss=2.904
# 2/2 [==============================] - 0s 4ms/step
# >3, 27/39, d_loss_real=0.317, d_loss_fake=0.124, g_loss=3.007
# 2/2 [==============================] - 0s 5ms/step
# >3, 28/39, d_loss_real=0.195, d_loss_fake=0.130, g_loss=3.473
# 2/2 [==============================] - 0s 5ms/step
# >3, 29/39, d_loss_real=0.327, d_loss_fake=0.097, g_loss=3.748
# 2/2 [==============================] - 0s 3ms/step
# >3, 30/39, d_loss_real=0.364, d_loss_fake=0.136, g_loss=4.363
# 2/2 [==============================] - 0s 3ms/step
# >3, 31/39, d_loss_real=0.286, d_loss_fake=0.103, g_loss=4.396
# 2/2 [==============================] - 0s 5ms/step
# >3, 32/39, d_loss_real=0.247, d_loss_fake=1.352, g_loss=8.366
# 2/2 [==============================] - 0s 4ms/step
# >3, 33/39, d_loss_real=0.550, d_loss_fake=0.004, g_loss=7.660
# 2/2 [==============================] - 0s 3ms/step
# >3, 34/39, d_loss_real=0.875, d_loss_fake=0.030, g_loss=3.878
# 2/2 [==============================] - 0s 3ms/step
# >3, 35/39, d_loss_real=0.607, d_loss_fake=0.201, g_loss=1.891
# 2/2 [==============================] - 0s 5ms/step
# >3, 36/39, d_loss_real=0.246, d_loss_fake=0.726, g_loss=1.297
# 2/2 [==============================] - 0s 5ms/step
# >3, 37/39, d_loss_real=0.228, d_loss_fake=0.664, g_loss=1.732
# 2/2 [==============================] - 0s 4ms/step
# >3, 38/39, d_loss_real=0.315, d_loss_fake=0.348, g_loss=2.292
# 2/2 [==============================] - 0s 4ms/step
# >3, 39/39, d_loss_real=0.539, d_loss_fake=0.223, g_loss=2.392
# 2/2 [==============================] - 0s 4ms/step
# >4, 1/39, d_loss_real=0.557, d_loss_fake=0.276, g_loss=1.899
# 2/2 [==============================] - 0s 7ms/step
# >4, 2/39, d_loss_real=0.129, d_loss_fake=0.315, g_loss=1.943
# 2/2 [==============================] - 0s 5ms/step
# >4, 3/39, d_loss_real=0.287, d_loss_fake=0.321, g_loss=1.831
# 2/2 [==============================] - 0s 5ms/step
# >4, 4/39, d_loss_real=0.300, d_loss_fake=0.357, g_loss=1.601
# 2/2 [==============================] - 0s 5ms/step
# >4, 5/39, d_loss_real=0.297, d_loss_fake=0.416, g_loss=1.384
# 2/2 [==============================] - 0s 5ms/step
# >4, 6/39, d_loss_real=0.198, d_loss_fake=0.465, g_loss=1.282
# 2/2 [==============================] - 0s 4ms/step
# >4, 7/39, d_loss_real=0.149, d_loss_fake=0.479, g_loss=1.301
# 2/2 [==============================] - 0s 5ms/step
# >4, 8/39, d_loss_real=0.184, d_loss_fake=0.438, g_loss=1.455
# 2/2 [==============================] - 0s 5ms/step
# >4, 9/39, d_loss_real=0.250, d_loss_fake=0.349, g_loss=1.512
# 2/2 [==============================] - 0s 4ms/step
# >4, 10/39, d_loss_real=0.275, d_loss_fake=0.358, g_loss=1.629
# 2/2 [==============================] - 0s 5ms/step
# >4, 11/39, d_loss_real=0.306, d_loss_fake=0.356, g_loss=1.721
# 2/2 [==============================] - 0s 7ms/step
# >4, 12/39, d_loss_real=0.275, d_loss_fake=0.324, g_loss=2.094
# 2/2 [==============================] - 0s 4ms/step
# >4, 13/39, d_loss_real=0.234, d_loss_fake=0.246, g_loss=2.730
# 2/2 [==============================] - 0s 5ms/step
# >4, 14/39, d_loss_real=0.295, d_loss_fake=0.122, g_loss=2.829
# 2/2 [==============================] - 0s 4ms/step
# >4, 15/39, d_loss_real=0.327, d_loss_fake=0.253, g_loss=3.501
# 2/2 [==============================] - 0s 6ms/step
# >4, 16/39, d_loss_real=0.306, d_loss_fake=0.071, g_loss=3.590
# 2/2 [==============================] - 0s 4ms/step
# >4, 17/39, d_loss_real=0.425, d_loss_fake=0.252, g_loss=3.577
# 2/2 [==============================] - 0s 7ms/step
# >4, 18/39, d_loss_real=0.375, d_loss_fake=0.172, g_loss=2.909
# 2/2 [==============================] - 0s 4ms/step
# >4, 19/39, d_loss_real=0.315, d_loss_fake=0.325, g_loss=2.850
# 2/2 [==============================] - 0s 5ms/step
# >4, 20/39, d_loss_real=0.220, d_loss_fake=0.217, g_loss=3.062
# 2/2 [==============================] - 0s 5ms/step
# >4, 21/39, d_loss_real=0.442, d_loss_fake=0.245, g_loss=2.664
# 2/2 [==============================] - 0s 5ms/step
# >4, 22/39, d_loss_real=0.399, d_loss_fake=0.292, g_loss=2.615
# 2/2 [==============================] - 0s 6ms/step
# >4, 23/39, d_loss_real=0.259, d_loss_fake=0.246, g_loss=2.642
# 2/2 [==============================] - 0s 4ms/step
# >4, 24/39, d_loss_real=0.274, d_loss_fake=0.381, g_loss=3.280
# 2/2 [==============================] - 0s 3ms/step
# >4, 25/39, d_loss_real=0.192, d_loss_fake=0.105, g_loss=4.043
# 2/2 [==============================] - 0s 5ms/step
# >4, 26/39, d_loss_real=0.288, d_loss_fake=0.093, g_loss=4.033
# 2/2 [==============================] - 0s 4ms/step
# >4, 27/39, d_loss_real=0.451, d_loss_fake=0.277, g_loss=5.324
# 2/2 [==============================] - 0s 5ms/step
# >4, 28/39, d_loss_real=0.542, d_loss_fake=0.057, g_loss=3.631
# 2/2 [==============================] - 0s 4ms/step
# >4, 29/39, d_loss_real=0.290, d_loss_fake=0.295, g_loss=4.842
# 2/2 [==============================] - 0s 4ms/step
# >4, 30/39, d_loss_real=0.459, d_loss_fake=0.051, g_loss=3.455
# 2/2 [==============================] - 0s 5ms/step
# >4, 31/39, d_loss_real=0.390, d_loss_fake=0.350, g_loss=2.277
# 2/2 [==============================] - 0s 5ms/step
# >4, 32/39, d_loss_real=0.403, d_loss_fake=0.513, g_loss=2.163
# 2/2 [==============================] - 0s 5ms/step
# >4, 33/39, d_loss_real=0.431, d_loss_fake=0.476, g_loss=1.827
# 2/2 [==============================] - 0s 4ms/step
# >4, 34/39, d_loss_real=0.526, d_loss_fake=0.638, g_loss=1.349
# 2/2 [==============================] - 0s 6ms/step
# >4, 35/39, d_loss_real=0.486, d_loss_fake=0.637, g_loss=1.340
# 2/2 [==============================] - 0s 5ms/step
# >4, 36/39, d_loss_real=0.218, d_loss_fake=0.581, g_loss=1.522
# 2/2 [==============================] - 0s 3ms/step
# >4, 37/39, d_loss_real=0.233, d_loss_fake=0.313, g_loss=1.779
# 2/2 [==============================] - 0s 6ms/step
# >4, 38/39, d_loss_real=0.246, d_loss_fake=0.277, g_loss=1.948
# 2/2 [==============================] - 0s 4ms/step
# >4, 39/39, d_loss_real=0.202, d_loss_fake=0.208, g_loss=1.981
# 2/2 [==============================] - 0s 7ms/step
# >5, 1/39, d_loss_real=0.154, d_loss_fake=0.210, g_loss=2.117
# 2/2 [==============================] - 0s 5ms/step
# >5, 2/39, d_loss_real=0.257, d_loss_fake=0.226, g_loss=2.120
# 2/2 [==============================] - 0s 5ms/step
# >5, 3/39, d_loss_real=0.268, d_loss_fake=0.393, g_loss=1.933
# 2/2 [==============================] - 0s 6ms/step
# >5, 4/39, d_loss_real=0.265, d_loss_fake=1.156, g_loss=3.097
# 2/2 [==============================] - 0s 5ms/step
# >5, 5/39, d_loss_real=0.595, d_loss_fake=0.230, g_loss=3.455
# 2/2 [==============================] - 0s 6ms/step
# >5, 6/39, d_loss_real=1.172, d_loss_fake=1.273, g_loss=3.453
# 2/2 [==============================] - 0s 5ms/step
# >5, 7/39, d_loss_real=1.244, d_loss_fake=0.111, g_loss=2.768
# 2/2 [==============================] - 0s 5ms/step
# >5, 8/39, d_loss_real=1.484, d_loss_fake=0.691, g_loss=1.666
# 2/2 [==============================] - 0s 5ms/step
# >5, 9/39, d_loss_real=0.933, d_loss_fake=0.435, g_loss=1.661
# 2/2 [==============================] - 0s 6ms/step
# >5, 10/39, d_loss_real=0.738, d_loss_fake=0.454, g_loss=1.694
# 2/2 [==============================] - 0s 5ms/step
# >5, 11/39, d_loss_real=0.868, d_loss_fake=0.386, g_loss=1.638
# 2/2 [==============================] - 0s 5ms/step
# >5, 12/39, d_loss_real=0.541, d_loss_fake=0.347, g_loss=1.684
# 2/2 [==============================] - 0s 5ms/step
# >5, 13/39, d_loss_real=0.589, d_loss_fake=0.316, g_loss=1.703
# 2/2 [==============================] - 0s 9ms/step
# >5, 14/39, d_loss_real=0.408, d_loss_fake=0.300, g_loss=1.691
# 2/2 [==============================] - 0s 7ms/step
# >5, 15/39, d_loss_real=0.671, d_loss_fake=0.318, g_loss=1.613
# 2/2 [==============================] - 0s 6ms/step
# >5, 16/39, d_loss_real=0.367, d_loss_fake=0.336, g_loss=1.566
# 2/2 [==============================] - 0s 3ms/step
# >5, 17/39, d_loss_real=0.401, d_loss_fake=0.333, g_loss=1.518
# 2/2 [==============================] - 0s 5ms/step
# >5, 18/39, d_loss_real=0.516, d_loss_fake=0.424, g_loss=1.395
# 2/2 [==============================] - 0s 7ms/step
# >5, 19/39, d_loss_real=0.389, d_loss_fake=0.484, g_loss=1.306
# 2/2 [==============================] - 0s 5ms/step
# >5, 20/39, d_loss_real=0.276, d_loss_fake=0.697, g_loss=1.425
# 2/2 [==============================] - 0s 10ms/step
# >5, 21/39, d_loss_real=0.450, d_loss_fake=0.591, g_loss=1.941
# 2/2 [==============================] - 0s 8ms/step
# >5, 22/39, d_loss_real=0.319, d_loss_fake=0.367, g_loss=2.875
# 2/2 [==============================] - 0s 3ms/step
# >5, 23/39, d_loss_real=0.551, d_loss_fake=0.078, g_loss=3.295
# 2/2 [==============================] - 0s 5ms/step
# >5, 24/39, d_loss_real=0.482, d_loss_fake=0.136, g_loss=3.112
# 2/2 [==============================] - 0s 4ms/step
# >5, 25/39, d_loss_real=0.234, d_loss_fake=0.141, g_loss=3.144
# 2/2 [==============================] - 0s 5ms/step
# >5, 26/39, d_loss_real=0.292, d_loss_fake=0.136, g_loss=3.337
# 2/2 [==============================] - 0s 6ms/step
# >5, 27/39, d_loss_real=0.414, d_loss_fake=0.124, g_loss=2.981
# 2/2 [==============================] - 0s 5ms/step
# >5, 28/39, d_loss_real=0.233, d_loss_fake=0.240, g_loss=2.914
# 2/2 [==============================] - 0s 4ms/step
# >5, 29/39, d_loss_real=0.317, d_loss_fake=0.249, g_loss=2.345
# 2/2 [==============================] - 0s 6ms/step
# >5, 30/39, d_loss_real=0.579, d_loss_fake=0.306, g_loss=2.020
# 2/2 [==============================] - 0s 3ms/step
# >5, 31/39, d_loss_real=0.380, d_loss_fake=0.387, g_loss=1.673
# 2/2 [==============================] - 0s 4ms/step
# >5, 32/39, d_loss_real=0.433, d_loss_fake=0.658, g_loss=1.286
# 2/2 [==============================] - 0s 5ms/step
# >5, 33/39, d_loss_real=0.343, d_loss_fake=0.697, g_loss=1.142
# 2/2 [==============================] - 0s 6ms/step
# >5, 34/39, d_loss_real=0.360, d_loss_fake=0.681, g_loss=1.245
# 2/2 [==============================] - 0s 5ms/step
# >5, 35/39, d_loss_real=0.436, d_loss_fake=0.535, g_loss=1.446
# 2/2 [==============================] - 0s 6ms/step
# >5, 36/39, d_loss_real=0.400, d_loss_fake=0.401, g_loss=1.547
# 2/2 [==============================] - 0s 6ms/step
# >5, 37/39, d_loss_real=0.228, d_loss_fake=0.356, g_loss=1.750
# 2/2 [==============================] - 0s 5ms/step
# >5, 38/39, d_loss_real=0.396, d_loss_fake=0.294, g_loss=1.903
# 2/2 [==============================] - 0s 5ms/step
# >5, 39/39, d_loss_real=0.326, d_loss_fake=0.251, g_loss=2.027
# 2/2 [==============================] - 0s 5ms/step
# >6, 1/39, d_loss_real=0.358, d_loss_fake=0.280, g_loss=2.185
# 2/2 [==============================] - 0s 6ms/step
# >6, 2/39, d_loss_real=0.403, d_loss_fake=0.210, g_loss=2.298
# 2/2 [==============================] - 0s 5ms/step
# >6, 3/39, d_loss_real=0.339, d_loss_fake=0.211, g_loss=2.320
# 2/2 [==============================] - 0s 4ms/step
# >6, 4/39, d_loss_real=0.313, d_loss_fake=0.185, g_loss=2.399
# 2/2 [==============================] - 0s 5ms/step
# >6, 5/39, d_loss_real=0.451, d_loss_fake=0.198, g_loss=2.297
# 2/2 [==============================] - 0s 6ms/step
# >6, 6/39, d_loss_real=0.345, d_loss_fake=0.244, g_loss=2.406
# 2/2 [==============================] - 0s 7ms/step
# >6, 7/39, d_loss_real=0.503, d_loss_fake=0.228, g_loss=2.093
# 2/2 [==============================] - 0s 5ms/step
# >6, 8/39, d_loss_real=0.396, d_loss_fake=0.343, g_loss=2.125
# 2/2 [==============================] - 0s 11ms/step
# >6, 9/39, d_loss_real=0.462, d_loss_fake=0.655, g_loss=2.250
# 2/2 [==============================] - 0s 5ms/step
# >6, 10/39, d_loss_real=0.639, d_loss_fake=0.640, g_loss=2.429
# 2/2 [==============================] - 0s 4ms/step
# >6, 11/39, d_loss_real=0.613, d_loss_fake=0.558, g_loss=2.705
# 2/2 [==============================] - 0s 4ms/step
# >6, 12/39, d_loss_real=0.779, d_loss_fake=0.333, g_loss=2.558
# 2/2 [==============================] - 0s 4ms/step
# >6, 13/39, d_loss_real=0.511, d_loss_fake=0.409, g_loss=2.984
# 2/2 [==============================] - 0s 8ms/step
# >6, 14/39, d_loss_real=0.519, d_loss_fake=0.134, g_loss=3.373
# 2/2 [==============================] - 0s 4ms/step
# >6, 15/39, d_loss_real=0.495, d_loss_fake=0.171, g_loss=3.295
# 2/2 [==============================] - 0s 4ms/step
# >6, 16/39, d_loss_real=0.437, d_loss_fake=0.221, g_loss=3.950
# 2/2 [==============================] - 0s 10ms/step
# >6, 17/39, d_loss_real=0.492, d_loss_fake=0.077, g_loss=3.385
# 2/2 [==============================] - 0s 7ms/step
# >6, 18/39, d_loss_real=0.394, d_loss_fake=0.230, g_loss=2.920
# 2/2 [==============================] - 0s 8ms/step
# >6, 19/39, d_loss_real=0.410, d_loss_fake=0.388, g_loss=2.844
# 2/2 [==============================] - 0s 6ms/step
# >6, 20/39, d_loss_real=0.756, d_loss_fake=0.374, g_loss=2.006
# 2/2 [==============================] - 0s 6ms/step
# >6, 21/39, d_loss_real=0.665, d_loss_fake=0.500, g_loss=1.433
# 2/2 [==============================] - 0s 6ms/step
# >6, 22/39, d_loss_real=0.395, d_loss_fake=0.385, g_loss=1.493
# 2/2 [==============================] - 0s 6ms/step
# >6, 23/39, d_loss_real=0.416, d_loss_fake=0.349, g_loss=1.540
# 2/2 [==============================] - 0s 5ms/step
# >6, 24/39, d_loss_real=0.223, d_loss_fake=0.291, g_loss=1.650
# 2/2 [==============================] - 0s 4ms/step
# >6, 25/39, d_loss_real=0.249, d_loss_fake=0.280, g_loss=1.602
# 2/2 [==============================] - 0s 5ms/step
# >6, 26/39, d_loss_real=0.164, d_loss_fake=0.300, g_loss=1.577
# 2/2 [==============================] - 0s 3ms/step
# >6, 27/39, d_loss_real=0.234, d_loss_fake=0.404, g_loss=1.519
# 2/2 [==============================] - 0s 4ms/step
# >6, 28/39, d_loss_real=0.332, d_loss_fake=0.438, g_loss=1.492
# 2/2 [==============================] - 0s 5ms/step
# >6, 29/39, d_loss_real=0.193, d_loss_fake=0.415, g_loss=1.453
# 2/2 [==============================] - 0s 5ms/step
# >6, 30/39, d_loss_real=0.162, d_loss_fake=0.421, g_loss=1.634
# 2/2 [==============================] - 0s 3ms/step
# >6, 31/39, d_loss_real=0.260, d_loss_fake=0.369, g_loss=1.915
# 2/2 [==============================] - 0s 4ms/step
# >6, 32/39, d_loss_real=0.487, d_loss_fake=0.302, g_loss=1.928
# 2/2 [==============================] - 0s 5ms/step
# >6, 33/39, d_loss_real=0.353, d_loss_fake=0.250, g_loss=2.006
# 2/2 [==============================] - 0s 5ms/step
# >6, 34/39, d_loss_real=0.422, d_loss_fake=0.284, g_loss=2.055
# 2/2 [==============================] - 0s 5ms/step
# >6, 35/39, d_loss_real=0.448, d_loss_fake=0.260, g_loss=2.144
# 2/2 [==============================] - 0s 4ms/step
# >6, 36/39, d_loss_real=0.335, d_loss_fake=0.239, g_loss=2.092
# 2/2 [==============================] - 0s 5ms/step
# >6, 37/39, d_loss_real=0.453, d_loss_fake=0.286, g_loss=1.992
# 2/2 [==============================] - 0s 5ms/step
# >6, 38/39, d_loss_real=0.407, d_loss_fake=0.292, g_loss=1.900
# 2/2 [==============================] - 0s 6ms/step
# >6, 39/39, d_loss_real=0.322, d_loss_fake=0.263, g_loss=1.919
# 2/2 [==============================] - 0s 8ms/step
# >7, 1/39, d_loss_real=0.755, d_loss_fake=0.404, g_loss=1.814
# 2/2 [==============================] - 0s 6ms/step
# >7, 2/39, d_loss_real=0.412, d_loss_fake=0.250, g_loss=1.932
# 2/2 [==============================] - 0s 5ms/step
# >7, 3/39, d_loss_real=0.376, d_loss_fake=0.284, g_loss=2.025
# 2/2 [==============================] - 0s 7ms/step
# >7, 4/39, d_loss_real=0.416, d_loss_fake=0.323, g_loss=2.347
# 2/2 [==============================] - 0s 6ms/step
# >7, 5/39, d_loss_real=0.402, d_loss_fake=0.206, g_loss=2.502
# 2/2 [==============================] - 0s 4ms/step
# >7, 6/39, d_loss_real=0.633, d_loss_fake=0.206, g_loss=2.067
# 2/2 [==============================] - 0s 6ms/step
# >7, 7/39, d_loss_real=0.462, d_loss_fake=0.457, g_loss=2.261
# 2/2 [==============================] - 0s 5ms/step
# >7, 8/39, d_loss_real=0.491, d_loss_fake=0.166, g_loss=2.470
# 2/2 [==============================] - 0s 6ms/step
# >7, 9/39, d_loss_real=0.494, d_loss_fake=0.295, g_loss=2.298
# 2/2 [==============================] - 0s 6ms/step
# >7, 10/39, d_loss_real=0.461, d_loss_fake=0.374, g_loss=2.391
# 2/2 [==============================] - 0s 5ms/step
# >7, 11/39, d_loss_real=0.566, d_loss_fake=0.275, g_loss=2.235
# 2/2 [==============================] - 0s 5ms/step
# >7, 12/39, d_loss_real=0.443, d_loss_fake=0.327, g_loss=2.533
# 2/2 [==============================] - 0s 6ms/step
# >7, 13/39, d_loss_real=0.734, d_loss_fake=0.309, g_loss=2.105
# 2/2 [==============================] - 0s 3ms/step
# >7, 14/39, d_loss_real=0.622, d_loss_fake=0.465, g_loss=2.116
# 2/2 [==============================] - 0s 5ms/step
# >7, 15/39, d_loss_real=0.724, d_loss_fake=0.354, g_loss=1.959
# 2/2 [==============================] - 0s 6ms/step
# >7, 16/39, d_loss_real=0.580, d_loss_fake=0.294, g_loss=1.952
# 2/2 [==============================] - 0s 7ms/step
# >7, 17/39, d_loss_real=0.602, d_loss_fake=0.342, g_loss=1.886
# 2/2 [==============================] - 0s 5ms/step
# >7, 18/39, d_loss_real=0.527, d_loss_fake=0.333, g_loss=1.764
# 2/2 [==============================] - 0s 5ms/step
# >7, 19/39, d_loss_real=0.534, d_loss_fake=0.336, g_loss=1.758
# 2/2 [==============================] - 0s 3ms/step
# >7, 20/39, d_loss_real=0.536, d_loss_fake=0.485, g_loss=1.619
# 2/2 [==============================] - 0s 5ms/step
# >7, 21/39, d_loss_real=0.479, d_loss_fake=0.717, g_loss=1.427
# 2/2 [==============================] - 0s 3ms/step
# >7, 22/39, d_loss_real=0.461, d_loss_fake=1.597, g_loss=1.198
# 2/2 [==============================] - 0s 6ms/step
# >7, 23/39, d_loss_real=0.636, d_loss_fake=2.316, g_loss=1.934
# 2/2 [==============================] - 0s 5ms/step
# >7, 24/39, d_loss_real=0.617, d_loss_fake=0.237, g_loss=2.911
# 2/2 [==============================] - 0s 6ms/step
# >7, 25/39, d_loss_real=0.584, d_loss_fake=0.109, g_loss=2.945
# 2/2 [==============================] - 0s 6ms/step
# >7, 26/39, d_loss_real=0.493, d_loss_fake=0.276, g_loss=3.885
# 2/2 [==============================] - 0s 4ms/step
# >7, 27/39, d_loss_real=0.413, d_loss_fake=0.056, g_loss=4.155
# 2/2 [==============================] - 0s 6ms/step
# >7, 28/39, d_loss_real=0.372, d_loss_fake=0.113, g_loss=3.740
# 2/2 [==============================] - 0s 6ms/step
# >7, 29/39, d_loss_real=0.421, d_loss_fake=0.158, g_loss=3.298
# 2/2 [==============================] - 0s 6ms/step
# >7, 30/39, d_loss_real=0.329, d_loss_fake=0.160, g_loss=3.006
# 2/2 [==============================] - 0s 7ms/step
# >7, 31/39, d_loss_real=0.355, d_loss_fake=0.281, g_loss=2.377
# 2/2 [==============================] - 0s 4ms/step
# >7, 32/39, d_loss_real=0.509, d_loss_fake=0.514, g_loss=2.264
# 2/2 [==============================] - 0s 6ms/step
# >7, 33/39, d_loss_real=0.525, d_loss_fake=0.287, g_loss=2.026
# 2/2 [==============================] - 0s 6ms/step
# >7, 34/39, d_loss_real=0.320, d_loss_fake=0.337, g_loss=1.881
# 2/2 [==============================] - 0s 7ms/step
# >7, 35/39, d_loss_real=0.419, d_loss_fake=0.386, g_loss=1.647
# 2/2 [==============================] - 0s 9ms/step
# >7, 36/39, d_loss_real=0.415, d_loss_fake=0.449, g_loss=1.396
# 2/2 [==============================] - 0s 5ms/step
# >7, 37/39, d_loss_real=0.324, d_loss_fake=0.552, g_loss=1.327
# 2/2 [==============================] - 0s 6ms/step
# >7, 38/39, d_loss_real=0.401, d_loss_fake=0.590, g_loss=1.385
# 2/2 [==============================] - 0s 7ms/step
# >7, 39/39, d_loss_real=0.461, d_loss_fake=0.465, g_loss=1.318
# 2/2 [==============================] - 0s 6ms/step
# >8, 1/39, d_loss_real=0.394, d_loss_fake=0.553, g_loss=1.428
# 2/2 [==============================] - 0s 6ms/step
# >8, 2/39, d_loss_real=0.325, d_loss_fake=0.349, g_loss=1.587
# 2/2 [==============================] - 0s 6ms/step
# >8, 3/39, d_loss_real=0.393, d_loss_fake=0.377, g_loss=1.611
# 2/2 [==============================] - 0s 6ms/step
# >8, 4/39, d_loss_real=0.399, d_loss_fake=0.322, g_loss=1.750
# 2/2 [==============================] - 0s 6ms/step
# >8, 5/39, d_loss_real=0.441, d_loss_fake=0.286, g_loss=1.762
# 2/2 [==============================] - 0s 5ms/step
# >8, 6/39, d_loss_real=0.383, d_loss_fake=0.209, g_loss=1.820
# 2/2 [==============================] - 0s 5ms/step
# >8, 7/39, d_loss_real=0.346, d_loss_fake=0.274, g_loss=1.959
# 2/2 [==============================] - 0s 4ms/step
# >8, 8/39, d_loss_real=0.294, d_loss_fake=0.265, g_loss=2.039
# 2/2 [==============================] - 0s 6ms/step
# >8, 9/39, d_loss_real=0.296, d_loss_fake=0.318, g_loss=2.057
# 2/2 [==============================] - 0s 5ms/step
# >8, 10/39, d_loss_real=0.416, d_loss_fake=0.403, g_loss=2.044
# 2/2 [==============================] - 0s 4ms/step
# >8, 11/39, d_loss_real=0.330, d_loss_fake=0.210, g_loss=2.148
# 2/2 [==============================] - 0s 8ms/step
# >8, 12/39, d_loss_real=0.440, d_loss_fake=0.199, g_loss=2.078
# 2/2 [==============================] - 0s 4ms/step
# >8, 13/39, d_loss_real=0.333, d_loss_fake=0.181, g_loss=2.164
# 2/2 [==============================] - 0s 4ms/step
# >8, 14/39, d_loss_real=0.310, d_loss_fake=0.302, g_loss=2.184
# 2/2 [==============================] - 0s 4ms/step
# >8, 15/39, d_loss_real=0.276, d_loss_fake=0.224, g_loss=2.174
# 2/2 [==============================] - 0s 5ms/step
# >8, 16/39, d_loss_real=0.214, d_loss_fake=0.240, g_loss=2.390
# 2/2 [==============================] - 0s 5ms/step
# >8, 17/39, d_loss_real=0.270, d_loss_fake=0.158, g_loss=2.369
# 2/2 [==============================] - 0s 5ms/step
# >8, 18/39, d_loss_real=0.307, d_loss_fake=0.250, g_loss=2.292
# 2/2 [==============================] - 0s 6ms/step
# >8, 19/39, d_loss_real=0.362, d_loss_fake=0.247, g_loss=2.187
# 2/2 [==============================] - 0s 5ms/step
# >8, 20/39, d_loss_real=0.334, d_loss_fake=0.210, g_loss=2.150
# 2/2 [==============================] - 0s 4ms/step
# >8, 21/39, d_loss_real=0.294, d_loss_fake=0.212, g_loss=1.982
# 2/2 [==============================] - 0s 5ms/step
# >8, 22/39, d_loss_real=0.360, d_loss_fake=0.226, g_loss=1.882
# 2/2 [==============================] - 0s 4ms/step
# >8, 23/39, d_loss_real=0.230, d_loss_fake=0.260, g_loss=1.897
# 2/2 [==============================] - 0s 5ms/step
# >8, 24/39, d_loss_real=0.324, d_loss_fake=0.322, g_loss=1.805
# 2/2 [==============================] - 0s 6ms/step
# >8, 25/39, d_loss_real=0.329, d_loss_fake=0.448, g_loss=1.812
# 2/2 [==============================] - 0s 4ms/step
# >8, 26/39, d_loss_real=0.347, d_loss_fake=0.291, g_loss=1.738
# 2/2 [==============================] - 0s 6ms/step
# >8, 27/39, d_loss_real=0.302, d_loss_fake=0.396, g_loss=1.689
# 2/2 [==============================] - 0s 6ms/step
# >8, 28/39, d_loss_real=0.412, d_loss_fake=0.325, g_loss=1.543
# 2/2 [==============================] - 0s 4ms/step
# >8, 29/39, d_loss_real=0.373, d_loss_fake=0.401, g_loss=1.526
# 2/2 [==============================] - 0s 5ms/step
# >8, 30/39, d_loss_real=0.373, d_loss_fake=0.364, g_loss=1.689
# 2/2 [==============================] - 0s 5ms/step
# >8, 31/39, d_loss_real=0.503, d_loss_fake=0.374, g_loss=1.655
# 2/2 [==============================] - 0s 4ms/step
# >8, 32/39, d_loss_real=0.311, d_loss_fake=0.341, g_loss=1.659
# 2/2 [==============================] - 0s 5ms/step
# >8, 33/39, d_loss_real=0.276, d_loss_fake=0.327, g_loss=1.650
# 2/2 [==============================] - 0s 4ms/step
# >8, 34/39, d_loss_real=0.292, d_loss_fake=0.325, g_loss=1.673
# 2/2 [==============================] - 0s 10ms/step
# >8, 35/39, d_loss_real=0.312, d_loss_fake=0.385, g_loss=1.701
# 2/2 [==============================] - 0s 5ms/step
# >8, 36/39, d_loss_real=0.383, d_loss_fake=0.324, g_loss=1.715
# 2/2 [==============================] - 0s 5ms/step
# >8, 37/39, d_loss_real=0.462, d_loss_fake=0.349, g_loss=1.756
# 2/2 [==============================] - 0s 5ms/step
# >8, 38/39, d_loss_real=0.435, d_loss_fake=0.478, g_loss=1.639
# 2/2 [==============================] - 0s 6ms/step
# >8, 39/39, d_loss_real=0.508, d_loss_fake=0.551, g_loss=1.737
# 2/2 [==============================] - 0s 6ms/step
# >9, 1/39, d_loss_real=0.414, d_loss_fake=0.384, g_loss=1.733
# 2/2 [==============================] - 0s 5ms/step
# >9, 2/39, d_loss_real=0.364, d_loss_fake=0.375, g_loss=1.798
# 2/2 [==============================] - 0s 5ms/step
# >9, 3/39, d_loss_real=0.357, d_loss_fake=0.329, g_loss=1.862
# 2/2 [==============================] - 0s 6ms/step
# >9, 4/39, d_loss_real=0.322, d_loss_fake=0.324, g_loss=1.860
# 2/2 [==============================] - 0s 4ms/step
# >9, 5/39, d_loss_real=0.378, d_loss_fake=0.332, g_loss=1.857
# 2/2 [==============================] - 0s 3ms/step
# >9, 6/39, d_loss_real=0.468, d_loss_fake=0.491, g_loss=2.157
# 2/2 [==============================] - 0s 7ms/step
# >9, 7/39, d_loss_real=0.333, d_loss_fake=0.304, g_loss=2.396
# 2/2 [==============================] - 0s 5ms/step
# >9, 8/39, d_loss_real=0.543, d_loss_fake=0.497, g_loss=2.219
# 2/2 [==============================] - 0s 6ms/step
# >9, 9/39, d_loss_real=0.488, d_loss_fake=0.422, g_loss=2.278
# 2/2 [==============================] - 0s 6ms/step
# >9, 10/39, d_loss_real=0.659, d_loss_fake=0.443, g_loss=2.956
# 2/2 [==============================] - 0s 6ms/step
# >9, 11/39, d_loss_real=0.935, d_loss_fake=0.625, g_loss=2.400
# 2/2 [==============================] - 0s 8ms/step
# >9, 12/39, d_loss_real=0.840, d_loss_fake=0.546, g_loss=2.200
# 2/2 [==============================] - 0s 4ms/step
# >9, 13/39, d_loss_real=0.957, d_loss_fake=0.505, g_loss=2.284
# 2/2 [==============================] - 0s 6ms/step
# >9, 14/39, d_loss_real=0.724, d_loss_fake=0.305, g_loss=2.420
# 2/2 [==============================] - 0s 3ms/step
# >9, 15/39, d_loss_real=0.788, d_loss_fake=0.435, g_loss=2.220
# 2/2 [==============================] - 0s 4ms/step
# >9, 16/39, d_loss_real=0.979, d_loss_fake=0.441, g_loss=2.181
# 2/2 [==============================] - 0s 6ms/step
# >9, 17/39, d_loss_real=0.732, d_loss_fake=0.276, g_loss=2.218
# 2/2 [==============================] - 0s 4ms/step
# >9, 18/39, d_loss_real=0.878, d_loss_fake=0.472, g_loss=1.921
# 2/2 [==============================] - 0s 4ms/step
# >9, 19/39, d_loss_real=0.700, d_loss_fake=0.650, g_loss=2.084
# 2/2 [==============================] - 0s 7ms/step
# >9, 20/39, d_loss_real=0.792, d_loss_fake=0.693, g_loss=2.462
# 2/2 [==============================] - 0s 6ms/step
# >9, 21/39, d_loss_real=0.709, d_loss_fake=0.469, g_loss=2.686
# 2/2 [==============================] - 0s 4ms/step
# >9, 22/39, d_loss_real=0.769, d_loss_fake=0.542, g_loss=3.029
# 2/2 [==============================] - 0s 8ms/step
# >9, 23/39, d_loss_real=0.894, d_loss_fake=0.282, g_loss=3.279
# 2/2 [==============================] - 0s 6ms/step
# >9, 24/39, d_loss_real=0.877, d_loss_fake=0.486, g_loss=2.922
# 2/2 [==============================] - 0s 4ms/step
# >9, 25/39, d_loss_real=0.415, d_loss_fake=0.375, g_loss=2.203
# 2/2 [==============================] - 0s 3ms/step
# >9, 26/39, d_loss_real=0.441, d_loss_fake=0.635, g_loss=1.864
# 2/2 [==============================] - 0s 5ms/step
# >9, 27/39, d_loss_real=0.582, d_loss_fake=0.661, g_loss=1.531
# 2/2 [==============================] - 0s 5ms/step
# >9, 28/39, d_loss_real=0.760, d_loss_fake=0.684, g_loss=1.620
# 2/2 [==============================] - 0s 7ms/step
# >9, 29/39, d_loss_real=0.709, d_loss_fake=0.547, g_loss=1.739
# 2/2 [==============================] - 0s 6ms/step
# >9, 30/39, d_loss_real=0.743, d_loss_fake=0.467, g_loss=1.760
# 2/2 [==============================] - 0s 5ms/step
# >9, 31/39, d_loss_real=0.907, d_loss_fake=0.421, g_loss=1.667
# 2/2 [==============================] - 0s 5ms/step
# >9, 32/39, d_loss_real=0.875, d_loss_fake=0.372, g_loss=1.662
# 2/2 [==============================] - 0s 5ms/step
# >9, 33/39, d_loss_real=0.727, d_loss_fake=0.418, g_loss=1.788
# 2/2 [==============================] - 0s 6ms/step
# >9, 34/39, d_loss_real=0.744, d_loss_fake=0.271, g_loss=2.081
# 2/2 [==============================] - 0s 5ms/step
# >9, 35/39, d_loss_real=0.697, d_loss_fake=0.245, g_loss=2.115
# 2/2 [==============================] - 0s 5ms/step
# >9, 36/39, d_loss_real=0.638, d_loss_fake=0.296, g_loss=2.123
# 2/2 [==============================] - 0s 5ms/step
# >9, 37/39, d_loss_real=0.700, d_loss_fake=0.316, g_loss=2.034
# 2/2 [==============================] - 0s 3ms/step
# >9, 38/39, d_loss_real=0.676, d_loss_fake=0.261, g_loss=1.841
# 2/2 [==============================] - 0s 5ms/step
# >9, 39/39, d_loss_real=0.588, d_loss_fake=0.361, g_loss=2.149
# 2/2 [==============================] - 0s 10ms/step
# >10, 1/39, d_loss_real=0.576, d_loss_fake=0.319, g_loss=2.080
# 2/2 [==============================] - 0s 5ms/step
# >10, 2/39, d_loss_real=0.577, d_loss_fake=0.244, g_loss=2.017
# 2/2 [==============================] - 0s 5ms/step
# >10, 3/39, d_loss_real=0.608, d_loss_fake=0.336, g_loss=1.796
# 2/2 [==============================] - 0s 6ms/step
# >10, 4/39, d_loss_real=0.569, d_loss_fake=0.452, g_loss=1.731
# 2/2 [==============================] - 0s 10ms/step
# >10, 5/39, d_loss_real=0.542, d_loss_fake=0.437, g_loss=1.600
# 2/2 [==============================] - 0s 4ms/step
# >10, 6/39, d_loss_real=0.644, d_loss_fake=0.648, g_loss=1.365
# 2/2 [==============================] - 0s 9ms/step
# >10, 7/39, d_loss_real=0.683, d_loss_fake=0.702, g_loss=1.227
# 2/2 [==============================] - 0s 5ms/step
# >10, 8/39, d_loss_real=0.945, d_loss_fake=0.749, g_loss=1.113
# 2/2 [==============================] - 0s 14ms/step
# >10, 9/39, d_loss_real=0.814, d_loss_fake=0.698, g_loss=1.047
# 2/2 [==============================] - 0s 4ms/step
# >10, 10/39, d_loss_real=0.815, d_loss_fake=0.706, g_loss=1.035
# 2/2 [==============================] - 0s 4ms/step
# >10, 11/39, d_loss_real=0.674, d_loss_fake=0.602, g_loss=1.132
# 2/2 [==============================] - 0s 4ms/step
# >10, 12/39, d_loss_real=0.739, d_loss_fake=0.612, g_loss=1.238
# 2/2 [==============================] - 0s 6ms/step
# >10, 13/39, d_loss_real=0.638, d_loss_fake=0.508, g_loss=1.297
# 2/2 [==============================] - 0s 4ms/step
# >10, 14/39, d_loss_real=0.558, d_loss_fake=0.474, g_loss=1.265
# 2/2 [==============================] - 0s 5ms/step
# >10, 15/39, d_loss_real=0.475, d_loss_fake=0.404, g_loss=1.377
# 2/2 [==============================] - 0s 4ms/step
# >10, 16/39, d_loss_real=0.480, d_loss_fake=0.393, g_loss=1.495
# 2/2 [==============================] - 0s 8ms/step
# >10, 17/39, d_loss_real=0.444, d_loss_fake=0.349, g_loss=1.589
# 2/2 [==============================] - 0s 5ms/step
# >10, 18/39, d_loss_real=0.377, d_loss_fake=0.408, g_loss=1.509
# 2/2 [==============================] - 0s 5ms/step
# >10, 19/39, d_loss_real=0.431, d_loss_fake=0.424, g_loss=1.489
# 2/2 [==============================] - 0s 10ms/step
# >10, 20/39, d_loss_real=0.488, d_loss_fake=0.552, g_loss=1.390
# 2/2 [==============================] - 0s 6ms/step
# >10, 21/39, d_loss_real=0.453, d_loss_fake=0.560, g_loss=1.496
# 2/2 [==============================] - 0s 5ms/step
# >10, 22/39, d_loss_real=0.433, d_loss_fake=0.524, g_loss=1.421
# 2/2 [==============================] - 0s 4ms/step
# >10, 23/39, d_loss_real=0.527, d_loss_fake=0.577, g_loss=1.510
# 2/2 [==============================] - 0s 5ms/step
# >10, 24/39, d_loss_real=0.695, d_loss_fake=0.581, g_loss=1.556
# 2/2 [==============================] - 0s 5ms/step
# >10, 25/39, d_loss_real=0.645, d_loss_fake=0.472, g_loss=1.534
# 2/2 [==============================] - 0s 3ms/step
# >10, 26/39, d_loss_real=0.693, d_loss_fake=0.599, g_loss=1.446
# 2/2 [==============================] - 0s 10ms/step
# >10, 27/39, d_loss_real=0.858, d_loss_fake=0.680, g_loss=1.433
# 2/2 [==============================] - 0s 5ms/step
# >10, 28/39, d_loss_real=0.968, d_loss_fake=0.482, g_loss=1.465
# 2/2 [==============================] - 0s 5ms/step
# >10, 29/39, d_loss_real=0.902, d_loss_fake=0.504, g_loss=1.324
# 2/2 [==============================] - 0s 5ms/step
# >10, 30/39, d_loss_real=0.855, d_loss_fake=0.556, g_loss=1.335
# 2/2 [==============================] - 0s 7ms/step
# >10, 31/39, d_loss_real=0.818, d_loss_fake=0.489, g_loss=1.264
# 2/2 [==============================] - 0s 6ms/step
# >10, 32/39, d_loss_real=0.656, d_loss_fake=0.441, g_loss=1.392
# 2/2 [==============================] - 0s 4ms/step
# >10, 33/39, d_loss_real=0.721, d_loss_fake=0.569, g_loss=1.509
# 2/2 [==============================] - 0s 9ms/step
# >10, 34/39, d_loss_real=0.818, d_loss_fake=0.406, g_loss=1.391
# 2/2 [==============================] - 0s 10ms/step
# >10, 35/39, d_loss_real=0.674, d_loss_fake=0.586, g_loss=1.364
# 2/2 [==============================] - 0s 4ms/step
# >10, 36/39, d_loss_real=0.751, d_loss_fake=0.474, g_loss=1.301
# 2/2 [==============================] - 0s 5ms/step
# >10, 37/39, d_loss_real=0.672, d_loss_fake=0.501, g_loss=1.325
# 2/2 [==============================] - 0s 5ms/step
# >10, 38/39, d_loss_real=0.795, d_loss_fake=0.496, g_loss=1.356
# 2/2 [==============================] - 0s 8ms/step
# >10, 39/39, d_loss_real=0.690, d_loss_fake=0.590, g_loss=1.237
# 5/5 [==============================] - 0s 55ms/step
# >Accuracy real: 49%, fake: 71%
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py:3103: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# 2/2 [==============================] - 0s 9ms/step
# >11, 1/39, d_loss_real=0.745, d_loss_fake=0.578, g_loss=1.292
# 2/2 [==============================] - 0s 5ms/step
# >11, 2/39, d_loss_real=0.774, d_loss_fake=0.665, g_loss=1.296
# 2/2 [==============================] - 0s 6ms/step
# >11, 3/39, d_loss_real=0.637, d_loss_fake=0.526, g_loss=1.226
# 2/2 [==============================] - 0s 5ms/step
# >11, 4/39, d_loss_real=0.731, d_loss_fake=0.419, g_loss=1.186
# 2/2 [==============================] - 0s 3ms/step
# >11, 5/39, d_loss_real=0.775, d_loss_fake=0.659, g_loss=1.294
# 2/2 [==============================] - 0s 5ms/step
# >11, 6/39, d_loss_real=0.632, d_loss_fake=0.530, g_loss=1.412
# 2/2 [==============================] - 0s 5ms/step
# >11, 7/39, d_loss_real=0.819, d_loss_fake=0.423, g_loss=1.348
# 2/2 [==============================] - 0s 3ms/step
# >11, 8/39, d_loss_real=0.636, d_loss_fake=0.416, g_loss=1.344
# 2/2 [==============================] - 0s 6ms/step
# >11, 9/39, d_loss_real=0.569, d_loss_fake=0.433, g_loss=1.473
# 2/2 [==============================] - 0s 4ms/step
# >11, 10/39, d_loss_real=0.611, d_loss_fake=0.477, g_loss=1.424
# 2/2 [==============================] - 0s 5ms/step
# >11, 11/39, d_loss_real=0.623, d_loss_fake=0.455, g_loss=1.547
# 2/2 [==============================] - 0s 5ms/step
# >11, 12/39, d_loss_real=0.708, d_loss_fake=0.372, g_loss=1.407
# 2/2 [==============================] - 0s 5ms/step
# >11, 13/39, d_loss_real=0.577, d_loss_fake=0.394, g_loss=1.481
# 2/2 [==============================] - 0s 4ms/step
# >11, 14/39, d_loss_real=0.578, d_loss_fake=0.392, g_loss=1.451
# 2/2 [==============================] - 0s 5ms/step
# >11, 15/39, d_loss_real=0.512, d_loss_fake=0.475, g_loss=1.303
# 2/2 [==============================] - 0s 5ms/step
# >11, 16/39, d_loss_real=0.527, d_loss_fake=0.538, g_loss=1.278
# 2/2 [==============================] - 0s 6ms/step
# >11, 17/39, d_loss_real=0.482, d_loss_fake=0.579, g_loss=1.182
# 2/2 [==============================] - 0s 6ms/step
# >11, 18/39, d_loss_real=0.502, d_loss_fake=0.598, g_loss=1.175
# 2/2 [==============================] - 0s 5ms/step
# >11, 19/39, d_loss_real=0.529, d_loss_fake=0.575, g_loss=1.098
# 2/2 [==============================] - 0s 5ms/step
# >11, 20/39, d_loss_real=0.543, d_loss_fake=0.583, g_loss=1.165
# 2/2 [==============================] - 0s 5ms/step
# >11, 21/39, d_loss_real=0.529, d_loss_fake=0.563, g_loss=1.212
# 2/2 [==============================] - 0s 3ms/step
# >11, 22/39, d_loss_real=0.590, d_loss_fake=0.487, g_loss=1.149
# 2/2 [==============================] - 0s 5ms/step
# >11, 23/39, d_loss_real=0.530, d_loss_fake=0.504, g_loss=1.202
# 2/2 [==============================] - 0s 5ms/step
# >11, 24/39, d_loss_real=0.572, d_loss_fake=0.466, g_loss=1.157
# 2/2 [==============================] - 0s 8ms/step
# >11, 25/39, d_loss_real=0.583, d_loss_fake=0.510, g_loss=1.184
# 2/2 [==============================] - 0s 6ms/step
# >11, 26/39, d_loss_real=0.524, d_loss_fake=0.506, g_loss=1.219
# 2/2 [==============================] - 0s 4ms/step
# >11, 27/39, d_loss_real=0.478, d_loss_fake=0.508, g_loss=1.249
# 2/2 [==============================] - 0s 4ms/step
# >11, 28/39, d_loss_real=0.570, d_loss_fake=0.446, g_loss=1.246
# 2/2 [==============================] - 0s 7ms/step
# >11, 29/39, d_loss_real=0.561, d_loss_fake=0.487, g_loss=1.232
# 2/2 [==============================] - 0s 4ms/step
# >11, 30/39, d_loss_real=0.540, d_loss_fake=0.503, g_loss=1.167
# ...
# 2/2 [==============================] - 0s 5ms/step
# >47, 19/39, d_loss_real=0.664, d_loss_fake=0.569, g_loss=1.001
# 2/2 [==============================] - 0s 7ms/step
# >47, 20/39, d_loss_real=0.675, d_loss_fake=0.627, g_loss=0.998
# 2/2 [==============================] - 0s 5ms/step
# >47, 21/39, d_loss_real=0.636, d_loss_fake=0.565, g_loss=0.971
# 2/2 [==============================] - 0s 5ms/step
# >47, 22/39, d_loss_real=0.614, d_loss_fake=0.625, g_loss=0.944
# 2/2 [==============================] - 0s 5ms/step
# >47, 23/39, d_loss_real=0.651, d_loss_fake=0.600, g_loss=0.944
# 2/2 [==============================] - 0s 5ms/step
# >47, 24/39, d_loss_real=0.621, d_loss_fake=0.615, g_loss=0.938
# 2/2 [==============================] - 0s 6ms/step
# >47, 25/39, d_loss_real=0.575, d_loss_fake=0.627, g_loss=0.858
# 2/2 [==============================] - 0s 9ms/step
# >47, 26/39, d_loss_real=0.523, d_loss_fake=0.661, g_loss=0.864
# 2/2 [==============================] - 0s 6ms/step
# >47, 27/39, d_loss_real=0.597, d_loss_fake=0.690, g_loss=0.925
# 2/2 [==============================] - 0s 5ms/step
# >47, 28/39, d_loss_real=0.628, d_loss_fake=0.630, g_loss=0.909
# 2/2 [==============================] - 0s 4ms/step
# >47, 29/39, d_loss_real=0.608, d_loss_fake=0.697, g_loss=0.902
# 2/2 [==============================] - 0s 5ms/step
# >47, 30/39, d_loss_real=0.633, d_loss_fake=0.652, g_loss=0.942
# 2/2 [==============================] - 0s 5ms/step
# >47, 31/39, d_loss_real=0.614, d_loss_fake=0.617, g_loss=0.980
# 2/2 [==============================] - 0s 4ms/step
# >47, 32/39, d_loss_real=0.625, d_loss_fake=0.616, g_loss=0.959
# 2/2 [==============================] - 0s 5ms/step
# >47, 33/39, d_loss_real=0.655, d_loss_fake=0.616, g_loss=0.940
# 2/2 [==============================] - 0s 5ms/step
# >47, 34/39, d_loss_real=0.557, d_loss_fake=0.584, g_loss=1.023
# 2/2 [==============================] - 0s 4ms/step
# >47, 35/39, d_loss_real=0.633, d_loss_fake=0.598, g_loss=1.045
# 2/2 [==============================] - 0s 5ms/step
# >47, 36/39, d_loss_real=0.500, d_loss_fake=0.550, g_loss=1.075
# 2/2 [==============================] - 0s 4ms/step
# >47, 37/39, d_loss_real=0.582, d_loss_fake=0.532, g_loss=1.095
# 2/2 [==============================] - 0s 5ms/step
# >47, 38/39, d_loss_real=0.516, d_loss_fake=0.540, g_loss=1.119
# 2/2 [==============================] - 0s 5ms/step
# >47, 39/39, d_loss_real=0.514, d_loss_fake=0.575, g_loss=1.031
# 2/2 [==============================] - 0s 6ms/step
# >48, 1/39, d_loss_real=0.547, d_loss_fake=0.599, g_loss=1.006
# 2/2 [==============================] - 0s 4ms/step
# >48, 2/39, d_loss_real=0.465, d_loss_fake=0.626, g_loss=1.077
# 2/2 [==============================] - 0s 4ms/step
# >48, 3/39, d_loss_real=0.501, d_loss_fake=0.648, g_loss=1.023
# 2/2 [==============================] - 0s 3ms/step
# >48, 4/39, d_loss_real=0.461, d_loss_fake=0.636, g_loss=1.023
# 2/2 [==============================] - 0s 4ms/step
# >48, 5/39, d_loss_real=0.540, d_loss_fake=0.612, g_loss=1.091
# 2/2 [==============================] - 0s 5ms/step
# >48, 6/39, d_loss_real=0.521, d_loss_fake=0.617, g_loss=1.064
# 2/2 [==============================] - 0s 5ms/step
# >48, 7/39, d_loss_real=0.570, d_loss_fake=0.597, g_loss=1.044
# 2/2 [==============================] - 0s 5ms/step
# >48, 8/39, d_loss_real=0.513, d_loss_fake=0.604, g_loss=1.116
# 2/2 [==============================] - 0s 8ms/step
# >48, 9/39, d_loss_real=0.537, d_loss_fake=0.613, g_loss=1.081
# 2/2 [==============================] - 0s 4ms/step
# >48, 10/39, d_loss_real=0.589, d_loss_fake=0.603, g_loss=1.187
# 2/2 [==============================] - 0s 5ms/step
# >48, 11/39, d_loss_real=0.620, d_loss_fake=0.550, g_loss=1.134
# 2/2 [==============================] - 0s 5ms/step
# >48, 12/39, d_loss_real=0.571, d_loss_fake=0.642, g_loss=1.121
# 2/2 [==============================] - 0s 6ms/step
# >48, 13/39, d_loss_real=0.516, d_loss_fake=0.594, g_loss=1.182
# 2/2 [==============================] - 0s 4ms/step
# >48, 14/39, d_loss_real=0.633, d_loss_fake=0.581, g_loss=1.328
# 2/2 [==============================] - 0s 7ms/step
# >48, 15/39, d_loss_real=0.671, d_loss_fake=0.556, g_loss=1.355
# 2/2 [==============================] - 0s 5ms/step
# >48, 16/39, d_loss_real=0.789, d_loss_fake=0.541, g_loss=1.250
# 2/2 [==============================] - 0s 7ms/step
# >48, 17/39, d_loss_real=0.654, d_loss_fake=0.571, g_loss=1.179
# 2/2 [==============================] - 0s 6ms/step
# >48, 18/39, d_loss_real=0.678, d_loss_fake=0.694, g_loss=1.146
# 2/2 [==============================] - 0s 5ms/step
# >48, 19/39, d_loss_real=0.566, d_loss_fake=0.624, g_loss=1.213
# 2/2 [==============================] - 0s 5ms/step
# >48, 20/39, d_loss_real=0.743, d_loss_fake=0.681, g_loss=1.117
# 2/2 [==============================] - 0s 3ms/step
# >48, 21/39, d_loss_real=0.752, d_loss_fake=0.637, g_loss=1.055
# 2/2 [==============================] - 0s 6ms/step
# >48, 22/39, d_loss_real=0.745, d_loss_fake=0.659, g_loss=1.029
# 2/2 [==============================] - 0s 6ms/step
# >48, 23/39, d_loss_real=0.772, d_loss_fake=0.616, g_loss=1.071
# 2/2 [==============================] - 0s 6ms/step
# >48, 24/39, d_loss_real=0.716, d_loss_fake=0.645, g_loss=1.088
# 2/2 [==============================] - 0s 6ms/step
# >48, 25/39, d_loss_real=0.693, d_loss_fake=0.590, g_loss=1.160
# 2/2 [==============================] - 0s 7ms/step
# >48, 26/39, d_loss_real=0.698, d_loss_fake=0.591, g_loss=1.171
# 2/2 [==============================] - 0s 3ms/step
# >48, 27/39, d_loss_real=0.608, d_loss_fake=0.493, g_loss=1.152
# 2/2 [==============================] - 0s 5ms/step
# >48, 28/39, d_loss_real=0.687, d_loss_fake=0.576, g_loss=1.158
# 2/2 [==============================] - 0s 4ms/step
# >48, 29/39, d_loss_real=0.671, d_loss_fake=0.551, g_loss=1.131
# 2/2 [==============================] - 0s 5ms/step
# >48, 30/39, d_loss_real=0.609, d_loss_fake=0.600, g_loss=1.090
# 2/2 [==============================] - 0s 7ms/step
# >48, 31/39, d_loss_real=0.624, d_loss_fake=0.594, g_loss=1.030
# 2/2 [==============================] - 0s 4ms/step
# >48, 32/39, d_loss_real=0.689, d_loss_fake=0.627, g_loss=0.984
# 2/2 [==============================] - 0s 10ms/step
# >48, 33/39, d_loss_real=0.598, d_loss_fake=0.583, g_loss=1.058
# 2/2 [==============================] - 0s 6ms/step
# >48, 34/39, d_loss_real=0.658, d_loss_fake=0.568, g_loss=1.033
# 2/2 [==============================] - 0s 5ms/step
# >48, 35/39, d_loss_real=0.683, d_loss_fake=0.570, g_loss=1.104
# 2/2 [==============================] - 0s 8ms/step
# >48, 36/39, d_loss_real=0.671, d_loss_fake=0.643, g_loss=1.049
# 2/2 [==============================] - 0s 4ms/step
# >48, 37/39, d_loss_real=0.623, d_loss_fake=0.547, g_loss=1.083
# 2/2 [==============================] - 0s 4ms/step
# >48, 38/39, d_loss_real=0.612, d_loss_fake=0.571, g_loss=1.063
# 2/2 [==============================] - 0s 4ms/step
# >48, 39/39, d_loss_real=0.607, d_loss_fake=0.556, g_loss=1.049
# 2/2 [==============================] - 0s 4ms/step
# >49, 1/39, d_loss_real=0.634, d_loss_fake=0.598, g_loss=1.050
# 2/2 [==============================] - 0s 6ms/step
# >49, 2/39, d_loss_real=0.605, d_loss_fake=0.579, g_loss=1.071
# 2/2 [==============================] - 0s 6ms/step
# >49, 3/39, d_loss_real=0.655, d_loss_fake=0.561, g_loss=1.088
# 2/2 [==============================] - 0s 4ms/step
# >49, 4/39, d_loss_real=0.646, d_loss_fake=0.605, g_loss=1.149
# 2/2 [==============================] - 0s 7ms/step
# >49, 5/39, d_loss_real=0.779, d_loss_fake=0.604, g_loss=1.161
# 2/2 [==============================] - 0s 5ms/step
# >49, 6/39, d_loss_real=0.647, d_loss_fake=0.624, g_loss=1.044
# 2/2 [==============================] - 0s 7ms/step
# >49, 7/39, d_loss_real=0.673, d_loss_fake=0.582, g_loss=1.050
# 2/2 [==============================] - 0s 5ms/step
# >49, 8/39, d_loss_real=0.566, d_loss_fake=0.567, g_loss=0.983
# 2/2 [==============================] - 0s 5ms/step
# >49, 9/39, d_loss_real=0.584, d_loss_fake=0.641, g_loss=1.052
# 2/2 [==============================] - 0s 5ms/step
# >49, 10/39, d_loss_real=0.572, d_loss_fake=0.592, g_loss=1.036
# 2/2 [==============================] - 0s 6ms/step
# >49, 11/39, d_loss_real=0.602, d_loss_fake=0.642, g_loss=0.996
# 2/2 [==============================] - 0s 6ms/step
# >49, 12/39, d_loss_real=0.679, d_loss_fake=0.630, g_loss=0.977
# 2/2 [==============================] - 0s 6ms/step
# >49, 13/39, d_loss_real=0.723, d_loss_fake=0.695, g_loss=0.923
# 2/2 [==============================] - 0s 5ms/step
# >49, 14/39, d_loss_real=0.626, d_loss_fake=0.646, g_loss=0.953
# 2/2 [==============================] - 0s 5ms/step
# >49, 15/39, d_loss_real=0.670, d_loss_fake=0.681, g_loss=0.862
# 2/2 [==============================] - 0s 4ms/step
# >49, 16/39, d_loss_real=0.719, d_loss_fake=0.793, g_loss=0.933
# 2/2 [==============================] - 0s 6ms/step
# >49, 17/39, d_loss_real=0.719, d_loss_fake=0.747, g_loss=0.892
# 2/2 [==============================] - 0s 5ms/step
# >49, 18/39, d_loss_real=0.697, d_loss_fake=0.709, g_loss=0.938
# 2/2 [==============================] - 0s 5ms/step
# >49, 19/39, d_loss_real=0.661, d_loss_fake=0.682, g_loss=0.934
# 2/2 [==============================] - 0s 4ms/step
# >49, 20/39, d_loss_real=0.558, d_loss_fake=0.638, g_loss=1.033
# 2/2 [==============================] - 0s 5ms/step
# >49, 21/39, d_loss_real=0.657, d_loss_fake=0.574, g_loss=1.051
# 2/2 [==============================] - 0s 5ms/step
# >49, 22/39, d_loss_real=0.670, d_loss_fake=0.548, g_loss=1.023
# 2/2 [==============================] - 0s 4ms/step
# >49, 23/39, d_loss_real=0.596, d_loss_fake=0.570, g_loss=1.018
# 2/2 [==============================] - 0s 5ms/step
# >49, 24/39, d_loss_real=0.626, d_loss_fake=0.631, g_loss=1.015
# 2/2 [==============================] - 0s 5ms/step
# >49, 25/39, d_loss_real=0.529, d_loss_fake=0.589, g_loss=1.035
# 2/2 [==============================] - 0s 5ms/step
# >49, 26/39, d_loss_real=0.515, d_loss_fake=0.524, g_loss=1.068
# 2/2 [==============================] - 0s 5ms/step
# >49, 27/39, d_loss_real=0.517, d_loss_fake=0.544, g_loss=1.115
# 2/2 [==============================] - 0s 5ms/step
# >49, 28/39, d_loss_real=0.534, d_loss_fake=0.526, g_loss=1.169
# 2/2 [==============================] - 0s 4ms/step
# >49, 29/39, d_loss_real=0.554, d_loss_fake=0.528, g_loss=1.153
# 2/2 [==============================] - 0s 4ms/step
# >49, 30/39, d_loss_real=0.524, d_loss_fake=0.557, g_loss=1.188
# 2/2 [==============================] - 0s 4ms/step
# >49, 31/39, d_loss_real=0.537, d_loss_fake=0.505, g_loss=1.225
# 2/2 [==============================] - 0s 4ms/step
# >49, 32/39, d_loss_real=0.571, d_loss_fake=0.489, g_loss=1.163
# 2/2 [==============================] - 0s 6ms/step
# >49, 33/39, d_loss_real=0.657, d_loss_fake=0.560, g_loss=1.119
# 2/2 [==============================] - 0s 5ms/step
# >49, 34/39, d_loss_real=0.519, d_loss_fake=0.555, g_loss=1.121
# 2/2 [==============================] - 0s 7ms/step
# >49, 35/39, d_loss_real=0.551, d_loss_fake=0.552, g_loss=1.151
# 2/2 [==============================] - 0s 6ms/step
# >49, 36/39, d_loss_real=0.584, d_loss_fake=0.516, g_loss=1.076
# 2/2 [==============================] - 0s 5ms/step
# >49, 37/39, d_loss_real=0.552, d_loss_fake=0.526, g_loss=1.139
# 2/2 [==============================] - 0s 5ms/step
# >49, 38/39, d_loss_real=0.530, d_loss_fake=0.619, g_loss=1.106
# 2/2 [==============================] - 0s 4ms/step
# >49, 39/39, d_loss_real=0.574, d_loss_fake=0.583, g_loss=1.101
# 2/2 [==============================] - 0s 3ms/step
# >50, 1/39, d_loss_real=0.586, d_loss_fake=0.630, g_loss=1.103
# 2/2 [==============================] - 0s 5ms/step
# >50, 2/39, d_loss_real=0.604, d_loss_fake=0.610, g_loss=1.047
# 2/2 [==============================] - 0s 5ms/step
# >50, 3/39, d_loss_real=0.687, d_loss_fake=0.608, g_loss=0.990
# 2/2 [==============================] - 0s 4ms/step
# >50, 4/39, d_loss_real=0.720, d_loss_fake=0.652, g_loss=0.951
# 2/2 [==============================] - 0s 4ms/step
# >50, 5/39, d_loss_real=0.643, d_loss_fake=0.648, g_loss=0.991
# 2/2 [==============================] - 0s 3ms/step
# >50, 6/39, d_loss_real=0.648, d_loss_fake=0.695, g_loss=0.992
# 2/2 [==============================] - 0s 5ms/step
# >50, 7/39, d_loss_real=0.678, d_loss_fake=0.600, g_loss=0.975
# 2/2 [==============================] - 0s 4ms/step
# >50, 8/39, d_loss_real=0.657, d_loss_fake=0.628, g_loss=1.029
# 2/2 [==============================] - 0s 3ms/step
# >50, 9/39, d_loss_real=0.689, d_loss_fake=0.536, g_loss=1.058
# 2/2 [==============================] - 0s 6ms/step
# >50, 10/39, d_loss_real=0.668, d_loss_fake=0.570, g_loss=1.042
# 2/2 [==============================] - 0s 3ms/step
# >50, 11/39, d_loss_real=0.615, d_loss_fake=0.624, g_loss=1.032
# 2/2 [==============================] - 0s 4ms/step
# >50, 12/39, d_loss_real=0.619, d_loss_fake=0.581, g_loss=1.079
# 2/2 [==============================] - 0s 5ms/step
# >50, 13/39, d_loss_real=0.626, d_loss_fake=0.603, g_loss=1.062
# 2/2 [==============================] - 0s 4ms/step
# >50, 14/39, d_loss_real=0.637, d_loss_fake=0.546, g_loss=1.098
# 2/2 [==============================] - 0s 5ms/step
# >50, 15/39, d_loss_real=0.622, d_loss_fake=0.611, g_loss=1.110
# 2/2 [==============================] - 0s 5ms/step
# >50, 16/39, d_loss_real=0.623, d_loss_fake=0.557, g_loss=1.064
# 2/2 [==============================] - 0s 6ms/step
# >50, 17/39, d_loss_real=0.564, d_loss_fake=0.574, g_loss=1.023
# 2/2 [==============================] - 0s 5ms/step
# >50, 18/39, d_loss_real=0.568, d_loss_fake=0.633, g_loss=1.063
# 2/2 [==============================] - 0s 4ms/step
# >50, 19/39, d_loss_real=0.551, d_loss_fake=0.536, g_loss=0.983
# 2/2 [==============================] - 0s 5ms/step
# >50, 20/39, d_loss_real=0.679, d_loss_fake=0.647, g_loss=0.918
# 2/2 [==============================] - 0s 5ms/step
# >50, 21/39, d_loss_real=0.590, d_loss_fake=0.689, g_loss=0.956
# 2/2 [==============================] - 0s 5ms/step
# >50, 22/39, d_loss_real=0.570, d_loss_fake=0.673, g_loss=0.942
# 2/2 [==============================] - 0s 5ms/step
# >50, 23/39, d_loss_real=0.549, d_loss_fake=0.707, g_loss=0.967
# 2/2 [==============================] - 0s 6ms/step
# >50, 24/39, d_loss_real=0.582, d_loss_fake=0.644, g_loss=0.960
# 2/2 [==============================] - 0s 5ms/step
# >50, 25/39, d_loss_real=0.573, d_loss_fake=0.607, g_loss=0.921
# 2/2 [==============================] - 0s 5ms/step
# >50, 26/39, d_loss_real=0.555, d_loss_fake=0.698, g_loss=0.900
# 2/2 [==============================] - 0s 4ms/step
# >50, 27/39, d_loss_real=0.532, d_loss_fake=0.673, g_loss=0.901
# 2/2 [==============================] - 0s 6ms/step
# >50, 28/39, d_loss_real=0.609, d_loss_fake=0.684, g_loss=0.850
# 2/2 [==============================] - 0s 6ms/step
# >50, 29/39, d_loss_real=0.567, d_loss_fake=0.653, g_loss=0.893
# 2/2 [==============================] - 0s 3ms/step
# >50, 30/39, d_loss_real=0.536, d_loss_fake=0.677, g_loss=0.844
# 2/2 [==============================] - 0s 6ms/step
# >50, 31/39, d_loss_real=0.561, d_loss_fake=0.650, g_loss=0.873
# 2/2 [==============================] - 0s 4ms/step
# >50, 32/39, d_loss_real=0.544, d_loss_fake=0.664, g_loss=0.921
# 2/2 [==============================] - 0s 4ms/step
# >50, 33/39, d_loss_real=0.572, d_loss_fake=0.621, g_loss=0.916
# 2/2 [==============================] - 0s 4ms/step
# >50, 34/39, d_loss_real=0.570, d_loss_fake=0.614, g_loss=0.890
# 2/2 [==============================] - 0s 5ms/step
# >50, 35/39, d_loss_real=0.531, d_loss_fake=0.648, g_loss=0.857
# 2/2 [==============================] - 0s 7ms/step
# >50, 36/39, d_loss_real=0.539, d_loss_fake=0.691, g_loss=0.874
# 2/2 [==============================] - 0s 4ms/step
# >50, 37/39, d_loss_real=0.498, d_loss_fake=0.636, g_loss=0.900
# 2/2 [==============================] - 0s 5ms/step
# >50, 38/39, d_loss_real=0.470, d_loss_fake=0.695, g_loss=0.962
# 2/2 [==============================] - 0s 6ms/step
# >50, 39/39, d_loss_real=0.487, d_loss_fake=0.664, g_loss=0.936
# 5/5 [==============================] - 0s 5ms/step
# >Accuracy real: 69%, fake: 67%
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.

# %%
def create_plot(examples, n):
    """
    Plot a grid of the generated images.

    Parameters:
    - examples: numpy array, the generated images to be plotted.
    - n: int, the dimension of the grid to display (e.g., n=3 for a 3x3 grid).
    """
    # Plot images in a grid of 'n x n'
    for i in range(n * n):
        # Define subplot
        pyplot.subplot(n, n, 1 + i)

        # Turn off axis to focus on the images
        pyplot.axis('off')

        # Plot raw pixel data
        pyplot.imshow(examples[i, :, :])

    # Display the plot
    pyplot.show()

# %%
# Generate images
latent_points = generate_latent_points(100, 100)
X = g_model.predict(latent_points)
X = (X + 1)/ 2.0

# Plot a 10x10 grid of the generated images
create_plot(X, 10)
# Out:
# 4/4 [==============================] - 0s 77ms/step
